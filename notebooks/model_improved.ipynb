# %%
import os, math, numpy as np, tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers

DATA_DIR = "../data/train"   # adjust ONLY if your images live elsewhere
BATCH    = 32
IMG_SZ   = 224
SEED     = 123
VAL_SPLIT = 0.2
AUTOTUNE = tf.data.AUTOTUNE

print(tf.__version__, keras.__version__)
# Out:
# 2.19.1 3.11.3

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    validation_split=VAL_SPLIT,
    subset="training",
    seed=SEED,
    image_size=(IMG_SZ, IMG_SZ),
    batch_size=BATCH,
    label_mode="binary",
    color_mode="rgb"      
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    validation_split=VAL_SPLIT,
    subset="validation",
    seed=SEED,
    image_size=(IMG_SZ, IMG_SZ),
    batch_size=BATCH,
    label_mode="binary",
    color_mode="rgb"       
)

# Normalize to [0,1]
norm = tf.keras.layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x,y: (norm(x), y), num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)
val_ds   = val_ds.map(lambda x,y: (norm(x), y),   num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)
# Out:
# Found 8005 files belonging to 2 classes.
# Using 6404 files for training.
# Found 8005 files belonging to 2 classes.
# Using 1601 files for validation.

# %%
data_augment = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
], name="augment")

norm = layers.Rescaling(1./255)

base = tf.keras.applications.MobileNetV2(
    include_top=False, weights="imagenet", input_shape=(IMG_SZ, IMG_SZ, 3)
)
base.trainable = False  # warm-up phase

inputs = keras.Input(shape=(IMG_SZ, IMG_SZ, 3), name="image")
x = norm(inputs)
x = data_augment(x)
x = base(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.4)(x)
x = layers.Dense(128, activation="relu", kernel_regularizer=regularizers.l2(1e-5))(x)
outputs = layers.Dense(1, activation="sigmoid", name="prob")(x)
model = keras.Model(inputs, outputs, name="catsdogs_efficientnetb0")

loss = keras.losses.BinaryCrossentropy(label_smoothing=0.05)
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss=loss,
    metrics=[keras.metrics.AUC(name="auc"), "accuracy",
             keras.metrics.Precision(name="precision"),
             keras.metrics.Recall(name="recall")]
)

ckpt = keras.callbacks.ModelCheckpoint(
    "../models/best_warmup.keras", monitor="val_auc", mode="max",
    save_best_only=True, verbose=1
)
es = keras.callbacks.EarlyStopping(
    monitor="val_auc", mode="max", patience=3, restore_best_weights=True, verbose=1
)

hist_warmup = model.fit(
    train_ds, validation_data=val_ds, epochs=10, callbacks=[ckpt, es]
)
# Out:
# Epoch 1/10
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.5011 - auc: 0.5064 - loss: 0.7549 - precision: 0.5050 - recall: 0.5067
# Epoch 1: val_auc improved from None to 0.56402, saving model to ../models/best_warmup.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 40s 186ms/step - accuracy: 0.5064 - auc: 0.5105 - loss: 0.7239 - precision: 0.5098 - recall: 0.5074 - val_accuracy: 0.4878 - val_auc: 0.5640 - val_loss: 0.7536 - val_precision: 0.4878 - val_recall: 1.0000
# Epoch 2/10
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.5069 - auc: 0.5055 - loss: 0.7104 - precision: 0.5070 - recall: 0.5598
# Epoch 2: val_auc did not improve from 0.56402
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 37s 183ms/step - accuracy: 0.5048 - auc: 0.4999 - loss: 0.7020 - precision: 0.5071 - recall: 0.5834 - val_accuracy: 0.4878 - val_auc: 0.5000 - val_loss: 0.6945 - val_precision: 0.4878 - val_recall: 1.0000
# Epoch 3/10
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.5079 - auc: 0.5065 - loss: 0.6953 - precision: 0.5115 - recall: 0.3558
# Epoch 3: val_auc did not improve from 0.56402
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 37s 186ms/step - accuracy: 0.5123 - auc: 0.5115 - loss: 0.6952 - precision: 0.5150 - recall: 0.5366 - val_accuracy: 0.4878 - val_auc: 0.5000 - val_loss: 0.6948 - val_precision: 0.4878 - val_recall: 1.0000
# Epoch 4/10
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.4973 - auc: 0.4898 - loss: 0.6952 - precision: 0.5001 - recall: 0.6528
# Epoch 4: val_auc did not improve from 0.56402
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 38s 187ms/step - accuracy: 0.4977 - auc: 0.4964 - loss: 0.6948 - precision: 0.5009 - recall: 0.5800 - val_accuracy: 0.4878 - val_auc: 0.5000 - val_loss: 0.6946 - val_precision: 0.4878 - val_recall: 1.0000
# Epoch 4: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %%
base.trainable = True
# unfreeze only the top ~40 layers (tweak 30–80 if you like)
for layer in base.layers[:-40]:
    layer.trainable = False

model.compile(
    optimizer=keras.optimizers.Adam(5e-5),  # tiny LR for fine-tune
    loss=loss,
    metrics=[keras.metrics.AUC(name="auc"), "accuracy",
             keras.metrics.Precision(name="precision"),
             keras.metrics.Recall(name="recall")]
)

ckpt_ft = keras.callbacks.ModelCheckpoint(
    "../models/best_finetune.keras", monitor="val_auc", mode="max",
    save_best_only=True, verbose=1
)
es_ft = keras.callbacks.EarlyStopping(
    monitor="val_auc", mode="max", patience=4, restore_best_weights=True, verbose=1
)
rlrop = keras.callbacks.ReduceLROnPlateau(
    monitor="val_auc", mode="max", factor=0.5, patience=2, min_lr=1e-6, verbose=1
)

hist_ft = model.fit(
    train_ds, validation_data=val_ds, epochs=20, callbacks=[ckpt_ft, es_ft, rlrop]
)
# Out:
# Epoch 1/20
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.5868 - auc: 0.6151 - loss: 0.6745 - precision: 0.5846 - recall: 0.6344
# Epoch 1: val_auc improved from None to 0.54619, saving model to ../models/best_finetune.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 52s 233ms/step - accuracy: 0.6146 - auc: 0.6584 - loss: 0.6581 - precision: 0.6161 - recall: 0.6222 - val_accuracy: 0.4878 - val_auc: 0.5462 - val_loss: 0.9614 - val_precision: 0.4878 - val_recall: 1.0000 - learning_rate: 5.0000e-05
# Epoch 2/20
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.6522 - auc: 0.7079 - loss: 0.6328 - precision: 0.6564 - recall: 0.6337
# Epoch 2: val_auc did not improve from 0.54619
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 47s 233ms/step - accuracy: 0.6568 - auc: 0.7129 - loss: 0.6296 - precision: 0.6644 - recall: 0.6430 - val_accuracy: 0.4878 - val_auc: 0.5312 - val_loss: 1.1113 - val_precision: 0.4878 - val_recall: 1.0000 - learning_rate: 5.0000e-05
# Epoch 3/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.6592 - auc: 0.7207 - loss: 0.6249 - precision: 0.6731 - recall: 0.6258
# Epoch 3: val_auc did not improve from 0.54619
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 47s 233ms/step - accuracy: 0.6611 - auc: 0.7240 - loss: 0.6218 - precision: 0.6701 - recall: 0.6439 - val_accuracy: 0.4878 - val_auc: 0.4802 - val_loss: 1.1111 - val_precision: 0.4878 - val_recall: 1.0000 - learning_rate: 5.0000e-05
# Epoch 4/20
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.6703 - auc: 0.7350 - loss: 0.6133 - precision: 0.6710 - recall: 0.6729
# Epoch 4: val_auc improved from 0.54619 to 0.54862, saving model to ../models/best_finetune.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 47s 235ms/step - accuracy: 0.6855 - auc: 0.7453 - loss: 0.6073 - precision: 0.6903 - recall: 0.6808 - val_accuracy: 0.4878 - val_auc: 0.5486 - val_loss: 0.9928 - val_precision: 0.4878 - val_recall: 1.0000 - learning_rate: 2.5000e-05
# Epoch 5/20
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.6734 - auc: 0.7396 - loss: 0.6121 - precision: 0.6808 - recall: 0.6646
# Epoch 5: val_auc improved from 0.54862 to 0.55811, saving model to ../models/best_finetune.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 47s 236ms/step - accuracy: 0.6814 - auc: 0.7473 - loss: 0.6061 - precision: 0.6877 - recall: 0.6728 - val_accuracy: 0.4878 - val_auc: 0.5581 - val_loss: 1.1847 - val_precision: 0.4878 - val_recall: 1.0000 - learning_rate: 2.5000e-05
# Epoch 6/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.6873 - auc: 0.7504 - loss: 0.6039 - precision: 0.6912 - recall: 0.6896
# Epoch 6: val_auc did not improve from 0.55811
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 47s 233ms/step - accuracy: 0.6924 - auc: 0.7580 - loss: 0.5981 - precision: 0.6947 - recall: 0.6939 - val_accuracy: 0.4878 - val_auc: 0.5228 - val_loss: 1.0828 - val_precision: 0.4878 - val_recall: 1.0000 - learning_rate: 2.5000e-05
# Epoch 7/20
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.6841 - auc: 0.7519 - loss: 0.6019 - precision: 0.6889 - recall: 0.6823
# Epoch 7: val_auc improved from 0.55811 to 0.57347, saving model to ../models/best_finetune.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 47s 234ms/step - accuracy: 0.6916 - auc: 0.7582 - loss: 0.5973 - precision: 0.6968 - recall: 0.6858 - val_accuracy: 0.4878 - val_auc: 0.5735 - val_loss: 1.0218 - val_precision: 0.4878 - val_recall: 1.0000 - learning_rate: 2.5000e-05
# Epoch 8/20
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.6831 - auc: 0.7516 - loss: 0.6029 - precision: 0.6840 - recall: 0.6902
# Epoch 8: val_auc improved from 0.57347 to 0.60990, saving model to ../models/best_finetune.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 47s 234ms/step - accuracy: 0.6893 - auc: 0.7570 - loss: 0.5985 - precision: 0.6933 - recall: 0.6864 - val_accuracy: 0.4878 - val_auc: 0.6099 - val_loss: 0.9363 - val_precision: 0.4878 - val_recall: 1.0000 - learning_rate: 2.5000e-05
# Epoch 9/20
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.6879 - auc: 0.7560 - loss: 0.5995 - precision: 0.6871 - recall: 0.6994
# Epoch 9: val_auc did not improve from 0.60990
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 47s 232ms/step - accuracy: 0.6944 - auc: 0.7639 - loss: 0.5932 - precision: 0.6985 - recall: 0.6914 - val_accuracy: 0.4878 - val_auc: 0.5572 - val_loss: 0.7244 - val_precision: 0.4878 - val_recall: 1.0000 - learning_rate: 2.5000e-05
# Epoch 10/20
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.6998 - auc: 0.7672 - loss: 0.5910 - precision: 0.7029 - recall: 0.6980
# Epoch 10: val_auc improved from 0.60990 to 0.66572, saving model to ../models/best_finetune.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 47s 235ms/step - accuracy: 0.6983 - auc: 0.7656 - loss: 0.5917 - precision: 0.7046 - recall: 0.6901 - val_accuracy: 0.5122 - val_auc: 0.6657 - val_loss: 0.7991 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 2.5000e-05
# Epoch 11/20
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6923 - auc: 0.7627 - loss: 0.5931 - precision: 0.6903 - recall: 0.6978
# Epoch 11: val_auc improved from 0.66572 to 0.67119, saving model to ../models/best_finetune.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 48s 240ms/step - accuracy: 0.6938 - auc: 0.7613 - loss: 0.5943 - precision: 0.6974 - recall: 0.6920 - val_accuracy: 0.5122 - val_auc: 0.6712 - val_loss: 0.8066 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 2.5000e-05
# Epoch 12/20
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.7024 - auc: 0.7657 - loss: 0.5928 - precision: 0.6957 - recall: 0.7274
# Epoch 12: val_auc did not improve from 0.67119
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 47s 234ms/step - accuracy: 0.7038 - auc: 0.7702 - loss: 0.5878 - precision: 0.7045 - recall: 0.7091 - val_accuracy: 0.5122 - val_auc: 0.6707 - val_loss: 1.3929 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 2.5000e-05
# Epoch 13/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.6971 - auc: 0.7661 - loss: 0.5898 - precision: 0.6937 - recall: 0.7172
# Epoch 13: val_auc improved from 0.67119 to 0.71185, saving model to ../models/best_finetune.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 47s 236ms/step - accuracy: 0.7041 - auc: 0.7728 - loss: 0.5851 - precision: 0.7054 - recall: 0.7078 - val_accuracy: 0.5122 - val_auc: 0.7118 - val_loss: 0.9549 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 2.5000e-05
# Epoch 14/20
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.7029 - auc: 0.7606 - loss: 0.5960 - precision: 0.7043 - recall: 0.7075
# Epoch 14: val_auc did not improve from 0.71185
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 47s 233ms/step - accuracy: 0.7042 - auc: 0.7658 - loss: 0.5908 - precision: 0.7063 - recall: 0.7063 - val_accuracy: 0.5128 - val_auc: 0.7087 - val_loss: 0.7024 - val_precision: 0.6667 - val_recall: 0.0026 - learning_rate: 2.5000e-05
# Epoch 15/20
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.6929 - auc: 0.7691 - loss: 0.5877 - precision: 0.6909 - recall: 0.7072
# Epoch 15: val_auc improved from 0.71185 to 0.71749, saving model to ../models/best_finetune.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 47s 235ms/step - accuracy: 0.7014 - auc: 0.7733 - loss: 0.5843 - precision: 0.7032 - recall: 0.7041 - val_accuracy: 0.5122 - val_auc: 0.7175 - val_loss: 0.8250 - val_precision: 0.5000 - val_recall: 0.0038 - learning_rate: 2.5000e-05
# Epoch 16/20
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.7089 - auc: 0.7759 - loss: 0.5822 - precision: 0.7114 - recall: 0.7113
# Epoch 16: val_auc did not improve from 0.71749
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 47s 234ms/step - accuracy: 0.7085 - auc: 0.7779 - loss: 0.5805 - precision: 0.7114 - recall: 0.7081 - val_accuracy: 0.5122 - val_auc: 0.7114 - val_loss: 1.0457 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 2.5000e-05
# Epoch 17/20
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.7102 - auc: 0.7784 - loss: 0.5796 - precision: 0.7182 - recall: 0.7035
# Epoch 17: val_auc did not improve from 0.71749
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 47s 234ms/step - accuracy: 0.7127 - auc: 0.7818 - loss: 0.5772 - precision: 0.7175 - recall: 0.7081 - val_accuracy: 0.5122 - val_auc: 0.7007 - val_loss: 0.9092 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 2.5000e-05
# Epoch 18/20
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.7031 - auc: 0.7721 - loss: 0.5852 - precision: 0.7005 - recall: 0.7119
# Epoch 18: val_auc improved from 0.71749 to 0.72704, saving model to ../models/best_finetune.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 47s 235ms/step - accuracy: 0.7121 - auc: 0.7812 - loss: 0.5775 - precision: 0.7136 - recall: 0.7150 - val_accuracy: 0.5122 - val_auc: 0.7270 - val_loss: 1.3743 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.2500e-05
# Epoch 19/20
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.7120 - auc: 0.7795 - loss: 0.5798 - precision: 0.7122 - recall: 0.7152
# Epoch 19: val_auc improved from 0.72704 to 0.72849, saving model to ../models/best_finetune.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 47s 234ms/step - accuracy: 0.7205 - auc: 0.7867 - loss: 0.5728 - precision: 0.7235 - recall: 0.7199 - val_accuracy: 0.5128 - val_auc: 0.7285 - val_loss: 0.8585 - val_precision: 1.0000 - val_recall: 0.0013 - learning_rate: 1.2500e-05
# Epoch 20/20
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.7111 - auc: 0.7811 - loss: 0.5774 - precision: 0.7090 - recall: 0.7255
# Epoch 20: val_auc improved from 0.72849 to 0.73877, saving model to ../models/best_finetune.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 47s 236ms/step - accuracy: 0.7197 - auc: 0.7919 - loss: 0.5676 - precision: 0.7188 - recall: 0.7280 - val_accuracy: 0.5240 - val_auc: 0.7388 - val_loss: 0.7138 - val_precision: 0.7879 - val_recall: 0.0333 - learning_rate: 1.2500e-05
# Restoring model weights from the end of the best epoch: 20.

# %%
from sklearn.metrics import f1_score

y_true, y_pred = [], []
for x, y in val_ds:
    p = model.predict(x, verbose=0).ravel()
    y_pred.append(p)
    y_true.append(y.numpy().ravel())
y_true = np.concatenate(y_true)
y_pred = np.concatenate(y_pred)

ths = np.linspace(0.2, 0.8, 61)
f1s = [f1_score(y_true, (y_pred >= t).astype(int)) for t in ths]
best_t = float(ths[int(np.argmax(f1s))])
print("Best threshold:", best_t)

with open("../models/threshold.txt","w") as f:
    f.write(str(best_t))
# Out:
# Best threshold: 0.25

# %%
# Keras 3 export -> SavedModel
model.export("../models/savedmodel_k3")
print("Saved SavedModel")

# (You run the converter from terminal next)
# Out:
# INFO:tensorflow:Assets written to: ../models/savedmodel_k3\assets
# INFO:tensorflow:Assets written to: ../models/savedmodel_k3\assets
# Saved artifact at '../models/savedmodel_k3'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='image')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   1740199581424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740199586176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740199588640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740199589344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740199580192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740274930384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740274926512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740274931792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740274929152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740171306864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740275821456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740275811072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740275817056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740275821808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740275816352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740168850848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740168844688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740168840816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740168848560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740168844160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740168850496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740168852784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740168847680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740161178384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740168846976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139437872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139432416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139434000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139442448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139439104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139443328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139440688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139444032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139434528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741453865936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139539872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139543392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741378825984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139539520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139531952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139533360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139540928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139530368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139536352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139542864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139995280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139992288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139992640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139987360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139994400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139996160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139998272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140000912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139999856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139990704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140055008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140055360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140055184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140055536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140060112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741392240256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741392248352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741392244656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741381990560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140054128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069064192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069075984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069061728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069066128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069071760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069075632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069074048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069065072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069070704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069075456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741483227472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741483219728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741483226240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741483219376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741483213568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741483225712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418313360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418307728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418313712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418313888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740274932672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740274925984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740274934608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740274930032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740274935312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740161355440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740161358608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740161354208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740161356848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740161365120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740161363536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740161366704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740161362304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740161364944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740161364240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276339584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276342928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276338352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276340992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276349264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276347680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276345568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276346448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276349088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276340288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418505216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418500464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418500288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418496064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418502576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418509264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418504336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418509968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418507856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418497296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418531824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418534992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418530592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418533232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418541504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418539920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418543088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418538688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418541328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1741418540624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276615824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276619168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276614592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276617232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276625504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276623920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276627088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276622688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276625328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276616528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276599440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276602608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276598208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276600848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276608768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276607184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276610528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276605952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276608592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740276605424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140071744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140074384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140070512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140072976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140080896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140079312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140082480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140078080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140080720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140080016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140186080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140188896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140184848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140186608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140195232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140193648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140196816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140192416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140195056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740140198576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069080048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069079520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069079696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069079168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069086736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069085152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069088496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069083920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069086560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069091664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069120384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069111760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069113696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069116688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069113168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069112464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069121264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069112640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069116160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069122144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069186096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069190144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069178000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069187152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069179584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069178704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069184160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069185744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069185920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069177824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069161264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069160736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069159856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069160384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069169536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069167952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069171296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069166720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069169360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069174464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069291456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069294096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069290048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069292688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069299024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069297440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069300608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069296208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069298848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069303600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069349408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069343072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069305184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069352928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069350464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069343776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069343600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069347296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069342368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069349584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069442256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069437856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069351872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069442960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069348352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069446656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069441376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069439440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069444720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069450880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069451760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069452112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069448416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069470272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069478544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069476960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069480128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069475728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069478368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069486288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069484000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069485232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069485408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069520128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069527344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069525760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069528928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069524528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069527168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069534032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069532448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069530336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069531216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740069533856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139789680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139780352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139204272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1740139207264: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved SavedModel
